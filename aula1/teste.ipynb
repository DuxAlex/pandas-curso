# %%
import pandas as pd

# %%
df = pd.read_csv('meu_arquivo.csv', encoding = 'latin1', sep = ';')

# %%
df
# Out:
#     Nome  Idade       Sexo
# 0   João     21  Masculino
# 1  Maria     18   Feminino
# 2  Pedro     34  Masculino
# 3  Joana     25   Feminino

# %%
df = pd.read_excel('meu_arquivo.xlsx')

# %% [markdown]
# #para ler arquivos excel precisa instalar pip install openpyxl

# %%
df
# Out:
#     Nome  Idade       Sexo
# 0   João     21  Masculino
# 1  Maria     18   Feminino
# 2  Pedro     34  Masculino
# 3  Joana     25   Feminino

# %%
#ler arquivo em html
tabela_wiki = pd.read_html('https://en.wikipedia.org/wiki/Minnesota')

# %%
tabela_wiki[1]
# Out:
#                    List of state symbols  \
#                          Living insignia
# 0                                   Bird
# 1                              Butterfly
# 2                                   Fish
# 3                                 Flower
# 4                               Mushroom
# 5                                   Tree
# 6                     Inanimate insignia
# 7                               Beverage
# 8                                   Food
# 9                               Gemstone
# 10                                 Other
# 11                         State quarter
# 12                      Released in 2005
# 13  Lists of United States state symbols
#
#
#                                     Living insignia.1
# 0                                         Common loon
# 1                                             Monarch
# 2                                             Walleye
# 3                       Pink-and-white lady's slipper
# ...

# %%
tabela_wiki
# Out:
# [                                            Minnesota  \
#  0                                               State
#  1                                            FlagSeal
#  2   Nicknames: Land of 10,000 Lakes; North Star St...
#  3   Motto: L'Étoile du Nord (French: The Star of t...
#  4                           Anthem: "Hail! Minnesota"
#  5   Map of the United States with Minnesota highli...
#  6                                             Country
#  7                                    Before statehood
#  8                               Admitted to the Union
#  9                                             Capital
#  10                                       Largest city
#  11                       Largest county or equivalent
#  12                      Largest metro and urban areas
#  13                                         Government
#  14                                         • Governor
#  15                              • Lieutenant Governor
# ...

# %%
type(tabela_wiki)
# Out:
# list

# %%
print(f'Total de {len(tabela_wiki)} tabelas')
# Out:
# Total de 28 tabelas

# %%
tabela_wiki_Largest_cities  = pd.read_html('https://en.wikipedia.org/wiki/Minnesota',match = 'Largest cities or towns in Minnesota')

# %%
tabela_wiki_Largest_cities[0]
# Out:
#    Largest cities or towns in Minnesota Source:[86]                         \
#                                  Unnamed: 0_level_1                   Rank
# 0                            Minneapolis Saint Paul                      1
# 1                            Minneapolis Saint Paul                      2
# 2                            Minneapolis Saint Paul                      3
# 3                            Minneapolis Saint Paul                      4
# 4                            Minneapolis Saint Paul                      5
# 5                            Minneapolis Saint Paul                      6
# 6                            Minneapolis Saint Paul                      7
# 7                            Minneapolis Saint Paul                      8
# 8                            Minneapolis Saint Paul                      9
# 9                            Minneapolis Saint Paul                     10
# ...

# %%
dados = [[1, 'alex', 'recife'],[2, 'augusto', 'paulista'],[3, 'jose', 'olinda']]

df = pd.DataFrame(dados, columns = ['id', 'nome','cidade'])

df.head()
# Out:
#    id     nome    cidade
# 0   1     alex    recife
# 1   2  augusto  paulista
# 2   3     jose    olinda

# %%
df.to_csv('novo_arquivo.csv', index = False, encoding ='latin1')

df.to_excel('novo_arquivo.xlsx', index = False)
