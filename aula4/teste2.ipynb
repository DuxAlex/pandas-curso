# %% [markdown]
# #TESTANDO USANDO O DROP PARA RETIRAR OS VALORES NULL

# %%
import pandas as pd

# %%
df = pd.read_excel('dados_niveis.xlsx')

# %%
df
# Out:
#           Dia  Nível (m)
# 0  2023-01-01       1.23
# 1  2023-01-02       1.24
# 2  2023-01-03       1.21
# 3  2023-01-04       1.19
# 4  2023-01-05       1.17
# 5  2023-01-06        NaN
# 6  2023-01-07        NaN
# 7  2023-01-08       1.15
# 8  2023-01-09       1.13
# 9  2023-01-10       1.12
# 10 2023-01-11       1.14
# 11 2023-01-12       1.18
# 12 2023-01-13        NaN
# 13 2023-01-14        NaN
# 14 2023-01-15        NaN
# 15 2023-01-16       1.45
# 16 2023-01-17       1.48
# 17 2023-01-18       1.55
# 18 2023-01-19       1.60
# 19 2023-01-20       1.65
# 20 2023-01-21        NaN

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#           Dia  Nível (m)
# 0  2023-01-01       1.23
# 1  2023-01-02       1.24
# 2  2023-01-03       1.21
# 3  2023-01-04       1.19
# 4  2023-01-05       1.17
# 7  2023-01-08       1.15
# 8  2023-01-09       1.13
# 9  2023-01-10       1.12
# 10 2023-01-11       1.14
# 11 2023-01-12       1.18
# 15 2023-01-16       1.45
# 16 2023-01-17       1.48
# 17 2023-01-18       1.55
# 18 2023-01-19       1.60
# 19 2023-01-20       1.65

# %%
df['Nível (m)'].plot() # EXECUTANDO O GRAFICO APOS RETIRAR OS VALORES NULOS
# Out:
# <Axes: >
